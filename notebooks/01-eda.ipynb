# %% [markdown]
# # Aula 1 — EDA e Forma Recente
#
# Exploração inicial dos dados do Brasileirão: tabela e cálculo da forma recente (últimas 5 partidas de cada time).

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
from src.data import preparar_dados
from src.data.paths import PARTIDAS_PROC, TABELA_PROC, FORMA_PROC
from src.data.forma import calcular_forma

# garante que os dados existem
preparar_dados.executar()

# %%
tabela = pd.read_csv(TABELA_PROC)
partidas = pd.read_csv(PARTIDAS_PROC)
tabela.head(20)

# %% [markdown]
# ## Forma recente
#
# Para cada time, pegamos as últimas 5 partidas em ordem cronológica e somamos os pontos (V=3, E=1, D=0).

# %%
forma = calcular_forma(partidas, n=5)
forma.head(20)

# %%
# distribuição de resultados (mando de campo importa?)
partidas['resultado'].value_counts(normalize=True).round(3)
